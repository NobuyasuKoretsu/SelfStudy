# %%
# 必要なライブラリの読み込み
import numpy as np
import numpy.random as random
import scipy as sp
import pandas as pd
from pandas import Series, DataFrame

# 可視化ライブラリ
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
# %matplotlib inline

# 小数第3位まで表示
# %precision 3
# Out:
# /Users/koretsunobuyasu/.pyenv/versions/3.7.5/lib/python3.7/site-packages/pandas/compat/__init__.py:117: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# '%.3f'

# %%
# 3列3行のデータを作成し、インデックスとカラムを設定
hier_df = DataFrame(
    np.arange(9).reshape((3, 3)),
    index = [
        ['a', 'a', 'b'],
        [1, 2, 2]
    ],
    columns=[
        ['Osaka', 'Tokyo', 'Osaka'],
        ['Blue', 'Red', 'Red']
    ]
)

display(hier_df)
# Out:
#     Osaka Tokyo Osaka
#      Blue   Red   Red
# a 1     0     1     2
#   2     3     4     5
# b 2     6     7     8

# %%
# indexに名前をつける
hier_df.index.names = ['key1', 'key2']
# カラムに名前をつける
hier_df.columns.names = ['city', 'color']
display(hier_df)
# Out:
# city      Osaka Tokyo Osaka
# color      Blue   Red   Red
# key1 key2
# a    1        0     1     2
#      2        3     4     5
# b    2        6     7     8

# %%
hier_df['Osaka']
# Out:
# color      Blue  Red
# key1 key2
# a    1        0    2
#      2        3    5
# b    2        6    8

# %%
# 階層ごとの要約統計量: 行合計
hier_df.sum(level = 'key2', axis=0)
# Out:
# city  Osaka Tokyo Osaka
# color  Blue   Red   Red
# key2
# 1         0     1     2
# 2         9    11    13

# %%
# 列合計
hier_df.sum(level='color', axis=1)
# Out:
# color      Blue  Red
# key1 key2
# a    1        0    3
#      2        3    9
# b    2        6   15

# %%
hier_df.drop(['b'])
# Out:
# city      Osaka Tokyo Osaka
# color      Blue   Red   Red
# key1 key2
# a    1        0     1     2
#      2        3     4     5

# %%
# データ1の準備
data1 = {
    'ID': ['100', '101', '102', '103', '104', '106', '108',  '110', '111', '113'],
    'City': ['Tokyo', 'Osaka', 'Kyoto', 'Hokkaido', 'Tokyo', 'Tokyo', 'Osaka', 'Kyoto', 'Hokkaido', 'Tokyo'],
    'Birth_Year': [1990, 1989, 1992, 1997, 1982, 1991, 1988, 1990, 1995, 1981],
    'Name': ['Hiroshi', 'Akiko', 'Yuki', 'Satoru', 'Steeve', 'Mituru', 'Aoi', 'Tarou', 'Suguru', 'Mitsuo']
}

df1 = DataFrame(data1)
display(df1)
# Out:
#     ID      City  Birth_Year     Name
# 0  100     Tokyo        1990  Hiroshi
# 1  101     Osaka        1989    Akiko
# 2  102     Kyoto        1992     Yuki
# 3  103  Hokkaido        1997   Satoru
# 4  104     Tokyo        1982   Steeve
# 5  106     Tokyo        1991   Mituru
# 6  108     Osaka        1988      Aoi
# 7  110     Kyoto        1990    Tarou
# 8  111  Hokkaido        1995   Suguru
# 9  113     Tokyo        1981   Mitsuo

# %%
# データ2の準備
data2 = {
    'ID': ['100', '101', '102', '105', '107'],
    'Math': [50, 43, 33, 76, 98],
    'English':[90, 30, 20, 50, 30],
    'Sex': ['M', 'F', 'F', 'M', 'M'],
    'Index_Num': [0, 1, 2, 3, 4]
}

df2 = DataFrame(data2)
display(df2)
# Out:
#     ID  Math  English Sex  Index_Num
# 0  100    50       90   M          0
# 1  101    43       30   F          1
# 2  102    33       20   F          2
# 3  105    76       50   M          3
# 4  107    98       30   M          4

# %%
# データのマージ(内部結合. キーは自動的に認識されるが、onで明示的に指定可能)
print('・結合テーブル')
pd.merge(df1, df2, on='ID')
# Out:
# ・結合テーブル
#     ID   City  Birth_Year     Name  Math  English Sex  Index_Num
# 0  100  Tokyo        1990  Hiroshi    50       90   M          0
# 1  101  Osaka        1989    Akiko    43       30   F          1
# 2  102  Kyoto        1992     Yuki    33       20   F          2

# %%
# データのマージ(全結合)
pd.merge(df1, df2, how='outer')
# Out:
#      ID      City  Birth_Year     Name  Math  English  Sex  Index_Num
# 0   100     Tokyo      1990.0  Hiroshi  50.0     90.0    M        0.0
# 1   101     Osaka      1989.0    Akiko  43.0     30.0    F        1.0
# 2   102     Kyoto      1992.0     Yuki  33.0     20.0    F        2.0
# 3   103  Hokkaido      1997.0   Satoru   NaN      NaN  NaN        NaN
# 4   104     Tokyo      1982.0   Steeve   NaN      NaN  NaN        NaN
# 5   106     Tokyo      1991.0   Mituru   NaN      NaN  NaN        NaN
# 6   108     Osaka      1988.0      Aoi   NaN      NaN  NaN        NaN
# 7   110     Kyoto      1990.0    Tarou   NaN      NaN  NaN        NaN
# 8   111  Hokkaido      1995.0   Suguru   NaN      NaN  NaN        NaN
# 9   113     Tokyo      1981.0   Mitsuo   NaN      NaN  NaN        NaN
# 10  105       NaN         NaN      NaN  76.0     50.0    M        3.0
# 11  107       NaN         NaN      NaN  98.0     30.0    M        4.0

# %%
# indexによるマージ
pd.merge(df1, df2, left_index = True, right_on = 'Index_Num')
# Out:
#   ID_x      City  Birth_Year     Name ID_y  Math  English Sex  Index_Num
# 0  100     Tokyo        1990  Hiroshi  100    50       90   M          0
# 1  101     Osaka        1989    Akiko  101    43       30   F          1
# 2  102     Kyoto        1992     Yuki  102    33       20   F          2
# 3  103  Hokkaido        1997   Satoru  105    76       50   M          3
# 4  104     Tokyo        1982   Steeve  107    98       30   M          4

# %%
# データのマージ(left)
pd.merge(df1, df2, how='left')
# Out:
#     ID      City  Birth_Year     Name  Math  English  Sex  Index_Num
# 0  100     Tokyo        1990  Hiroshi  50.0     90.0    M        0.0
# 1  101     Osaka        1989    Akiko  43.0     30.0    F        1.0
# 2  102     Kyoto        1992     Yuki  33.0     20.0    F        2.0
# 3  103  Hokkaido        1997   Satoru   NaN      NaN  NaN        NaN
# 4  104     Tokyo        1982   Steeve   NaN      NaN  NaN        NaN
# 5  106     Tokyo        1991   Mituru   NaN      NaN  NaN        NaN
# 6  108     Osaka        1988      Aoi   NaN      NaN  NaN        NaN
# 7  110     Kyoto        1990    Tarou   NaN      NaN  NaN        NaN
# 8  111  Hokkaido        1995   Suguru   NaN      NaN  NaN        NaN
# 9  113     Tokyo        1981   Mitsuo   NaN      NaN  NaN        NaN

# %%
# データのマージ(right)
pd.merge(df1, df2, how='right')
# Out:
#     ID   City  Birth_Year     Name  Math  English Sex  Index_Num
# 0  100  Tokyo      1990.0  Hiroshi    50       90   M          0
# 1  101  Osaka      1989.0    Akiko    43       30   F          1
# 2  102  Kyoto      1992.0     Yuki    33       20   F          2
# 3  105    NaN         NaN      NaN    76       50   M          3
# 4  107    NaN         NaN      NaN    98       30   M          4

# %%
# データ3の準備
data3 = {
    'ID': ['117', '118', '119', '120', '125'],
    'City': ['Chiba', 'Kanagawa', 'Tokyo', 'Fukuoka', 'Okinawa'],
    'Birth_Year': [1990, 1989, 1992, 1997, 1982],
    'Name': ['Suguru', 'Kouichi', 'Satochi', 'Yukie', 'Akari']
}
df3 = DataFrame(data3)
display(df3)
# Out:
#     ID      City  Birth_Year     Name
# 0  117     Chiba        1990   Suguru
# 1  118  Kanagawa        1989  Kouichi
# 2  119     Tokyo        1992  Satochi
# 3  120   Fukuoka        1997    Yukie
# 4  125   Okinawa        1982    Akari

# %%
# concat 縦結合
concat_data = pd.concat([df1, df3])
display(concat_data)
# Out:
#     ID      City  Birth_Year     Name
# 0  100     Tokyo        1990  Hiroshi
# 1  101     Osaka        1989    Akiko
# 2  102     Kyoto        1992     Yuki
# 3  103  Hokkaido        1997   Satoru
# 4  104     Tokyo        1982   Steeve
# 5  106     Tokyo        1991   Mituru
# 6  108     Osaka        1988      Aoi
# 7  110     Kyoto        1990    Tarou
# 8  111  Hokkaido        1995   Suguru
# 9  113     Tokyo        1981   Mitsuo
# 0  117     Chiba        1990   Suguru
# 1  118  Kanagawa        1989  Kouichi
# 2  119     Tokyo        1992  Satochi
# 3  120   Fukuoka        1997    Yukie
# 4  125   Okinawa        1982    Akari

# %%
# hier_dfを用意
hier_df = DataFrame(
    np.arange(9).reshape((3, 3)),
    index = [
       ['a', 'a', 'b'] ,
       [1, 2, 2],
    ],
    columns = [
        ['Osaka', 'Tokyo', 'Osaka'],
        ['Blue', 'Red', 'Red']
    ]
)

display(hier_df)
# Out:
#     Osaka Tokyo Osaka
#      Blue   Red   Red
# a 1     0     1     2
#   2     3     4     5
# b 2     6     7     8

# %%
# ピボット操作で「Blue, Red」の列を行に変更
hier_df.stack()
# Out:
#           Osaka  Tokyo
# a 1 Blue      0    NaN
#     Red       2    1.0
#   2 Blue      3    NaN
#     Red       5    4.0
# b 2 Blue      6    NaN
#     Red       8    7.0

# %%
# unstackメソッドで「Blue, Red」の行を列に変更
hier_df.stack().unstack()
# Out:
#     Osaka     Tokyo
#      Blue Red  Blue  Red
# a 1     0   2   NaN  1.0
#   2     3   5   NaN  4.0
# b 2     6   8   NaN  7.0

# %%
# 重複のあるデータ
dupli_data = DataFrame(
    {
        'col1': [1, 1, 2, 3, 4, 4, 6, 6],
        'col2': ['a', 'b', 'b', 'b', 'c', 'c', 'b', 'b']
    }
)
print('・元のデータ')
display(dupli_data)
# Out:
# ・元のデータ
#    col1 col2
# 0     1    a
# 1     1    b
# 2     2    b
# 3     3    b
# 4     4    c
# 5     4    c
# 6     6    b
# 7     6    b

# %%
# 重複判定
dupli_data.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6    False
# 7     True
# dtype: bool

# %%
# 重複削除
dupli_data.drop_duplicates()
# Out:
#    col1 col2
# 0     1    a
# 1     1    b
# 2     2    b
# 3     3    b
# 4     4    c
# 6     6    b

# %%
# 参照データ
city_map = {
    'Tokyo': 'Kanto',
    'Hokkaido': 'Hokkaido',
    'Osaka': 'Kansai',
    'Kyoto': 'Kansai'
}
city_map
# Out:
# {'Tokyo': 'Kanto',
#  'Hokkaido': 'Hokkaido',
#  'Osaka': 'Kansai',
#  'Kyoto': 'Kansai'}

# %%
# 参照データを結合
# もし対応するデータがなかったらNaNになる
df1['Region'] = df1['City'] .map(city_map)
display(df1)
# Out:
#     ID      City  Birth_Year     Name    Region
# 0  100     Tokyo        1990  Hiroshi     Kanto
# 1  101     Osaka        1989    Akiko    Kansai
# 2  102     Kyoto        1992     Yuki    Kansai
# 3  103  Hokkaido        1997   Satoru  Hokkaido
# 4  104     Tokyo        1982   Steeve     Kanto
# 5  106     Tokyo        1991   Mituru     Kanto
# 6  108     Osaka        1988      Aoi    Kansai
# 7  110     Kyoto        1990    Tarou    Kansai
# 8  111  Hokkaido        1995   Suguru  Hokkaido
# 9  113     Tokyo        1981   Mitsuo     Kanto

# %%
# Birth_Yearの上3つの数字・文字を取り出す
df1['Up_two_Num'] = df1['Birth_Year'].map(lambda x: str(x)[0:3])
df1
# Out:
#     ID      City  Birth_Year     Name    Region Up_two_Num
# 0  100     Tokyo        1990  Hiroshi     Kanto        199
# 1  101     Osaka        1989    Akiko    Kansai        198
# 2  102     Kyoto        1992     Yuki    Kansai        199
# 3  103  Hokkaido        1997   Satoru  Hokkaido        199
# 4  104     Tokyo        1982   Steeve     Kanto        198
# 5  106     Tokyo        1991   Mituru     Kanto        199
# 6  108     Osaka        1988      Aoi    Kansai        198
# 7  110     Kyoto        1990    Tarou    Kansai        199
# 8  111  Hokkaido        1995   Suguru  Hokkaido        199
# 9  113     Tokyo        1981   Mitsuo     Kanto        198

# %%
# 分割の粒度
birth_year_bins = [1980, 1985, 1990, 1995, 2000]

# ビン分割の実施
Birth_Year_cut_data = pd.cut(df1.Birth_Year, birth_year_bins)
display(Birth_Year_cut_data)
# Out:
# 0    (1985, 1990]
# 1    (1985, 1990]
# 2    (1990, 1995]
# 3    (1995, 2000]
# 4    (1980, 1985]
# 5    (1990, 1995]
# 6    (1985, 1990]
# 7    (1985, 1990]
# 8    (1990, 1995]
# 9    (1980, 1985]
# Name: Birth_Year, dtype: category
# Categories (4, interval[int64]): [(1980, 1985] < (1985, 1990] < (1990, 1995] < (1995, 2000]]

# %%
# 集計結果
pd.value_counts(Birth_Year_cut_data)
# Out:
# (1985, 1990]    4
# (1990, 1995]    3
# (1980, 1985]    2
# (1995, 2000]    1
# Name: Birth_Year, dtype: int64

# %%
# 名前をつける
group_names = ['early1980s', 'late1980s', 'early1990s', 'late1990s']
Birth_Year_cut_data = pd.cut(df1.Birth_Year, birth_year_bins, labels = group_names)
pd.value_counts(Birth_Year_cut_data)
# Out:
# late1980s     4
# early1990s    3
# early1980s    2
# late1990s     1
# Name: Birth_Year, dtype: int64

# %%
# 数字で分割数指定可能.  ここでは2つに分割
pd.cut(df1.Birth_Year, 2)
# Out:
# 0      (1989.0, 1997.0]
# 1    (1980.984, 1989.0]
# 2      (1989.0, 1997.0]
# 3      (1989.0, 1997.0]
# 4    (1980.984, 1989.0]
# 5      (1989.0, 1997.0]
# 6    (1980.984, 1989.0]
# 7      (1989.0, 1997.0]
# 8      (1989.0, 1997.0]
# 9    (1980.984, 1989.0]
# Name: Birth_Year, dtype: category
# Categories (2, interval[float64]): [(1980.984, 1989.0] < (1989.0, 1997.0]]

# %%
pd.value_counts(pd.qcut(df1.Birth_Year, 2))
# Out:
# (1980.999, 1990.0]    6
# (1990.0, 1997.0]      4
# Name: Birth_Year, dtype: int64

# %%
# データを用意(確認), ただしregionつき
df1
# Out:
#     ID      City  Birth_Year     Name    Region Up_two_Num
# 0  100     Tokyo        1990  Hiroshi     Kanto        199
# 1  101     Osaka        1989    Akiko    Kansai        198
# 2  102     Kyoto        1992     Yuki    Kansai        199
# 3  103  Hokkaido        1997   Satoru  Hokkaido        199
# 4  104     Tokyo        1982   Steeve     Kanto        198
# 5  106     Tokyo        1991   Mituru     Kanto        199
# 6  108     Osaka        1988      Aoi    Kansai        198
# 7  110     Kyoto        1990    Tarou    Kansai        199
# 8  111  Hokkaido        1995   Suguru  Hokkaido        199
# 9  113     Tokyo        1981   Mitsuo     Kanto        198

# %%
# サイス情報
df1.groupby('City').size()
# Out:
# City
# Hokkaido    2
# Kyoto       2
# Osaka       2
# Tokyo       4
# dtype: int64

# %%
# cityを軸に、Birth_Yearの平均値を求める
df1.groupby('City')['Birth_Year'].mean()
# Out:
# City
# Hokkaido    1996.0
# Kyoto       1991.0
# Osaka       1988.5
# Tokyo       1986.0
# Name: Birth_Year, dtype: float64

# %%
df1.groupby(
    ['Region', 'City'],
    as_index=False
)['Birth_Year'].mean()
# Out:
#      Region      City  Birth_Year
# 0  Hokkaido  Hokkaido      1996.0
# 1    Kansai     Kyoto      1991.0
# 2    Kansai     Osaka      1988.5
# 3     Kanto     Tokyo      1986.0

# %%
for group, subdf in df1.groupby('Region'):
    print("======================================================")
    print(f'Region Name: {group}')
    print(subdf)
# Out:
# ======================================================
# Region Name: Hokkaido
#     ID      City  Birth_Year    Name    Region Up_two_Num
# 3  103  Hokkaido        1997  Satoru  Hokkaido        199
# 8  111  Hokkaido        1995  Suguru  Hokkaido        199
# ======================================================
# Region Name: Kansai
#     ID   City  Birth_Year   Name  Region Up_two_Num
# 1  101  Osaka        1989  Akiko  Kansai        198
# 2  102  Kyoto        1992   Yuki  Kansai        199
# 6  108  Osaka        1988    Aoi  Kansai        198
# 7  110  Kyoto        1990  Tarou  Kansai        199
# ======================================================
# Region Name: Kanto
#     ID   City  Birth_Year     Name Region Up_two_Num
# 0  100  Tokyo        1990  Hiroshi  Kanto        199
# 4  104  Tokyo        1982   Steeve  Kanto        198
# 5  106  Tokyo        1991   Mituru  Kanto        199
# 9  113  Tokyo        1981   Mitsuo  Kanto        198

# %%
# データの準備
import numpy as np
from numpy import nan as NA
import pandas as pd

df = pd.DataFrame(np.random.rand(10, 4))

# NAにする
df.iloc[1, 0] = NA
df.iloc[2:3, 2] = NA
df.iloc[5:, 3] = NA

# %%
display(df)
# Out:
#           0         1         2         3
# 0  0.199320  0.632975  0.310385  0.937925
# 1       NaN  0.621555  0.491349  0.237890
# 2  0.657604  0.722652       NaN  0.974276
# 3  0.011049  0.584734  0.086839  0.993345
# 4  0.075121  0.664065  0.953025  0.446472
# 5  0.700973  0.819059  0.895355       NaN
# 6  0.075758  0.935040  0.380271       NaN
# 7  0.670879  0.699581  0.185698       NaN
# 8  0.442609  0.636605  0.240343       NaN
# 9  0.767131  0.269840  0.945019       NaN

# %%
df.dropna()
# Out:
#           0         1         2         3
# 0  0.199320  0.632975  0.310385  0.937925
# 3  0.011049  0.584734  0.086839  0.993345
# 4  0.075121  0.664065  0.953025  0.446472

# %%
df[[0, 1]].dropna()
# Out:
#           0         1
# 0  0.199320  0.632975
# 2  0.657604  0.722652
# 3  0.011049  0.584734
# 4  0.075121  0.664065
# 5  0.700973  0.819059
# 6  0.075758  0.935040
# 7  0.670879  0.699581
# 8  0.442609  0.636605
# 9  0.767131  0.269840

# %%
df.fillna(0)
# Out:
#           0         1         2         3
# 0  0.199320  0.632975  0.310385  0.937925
# 1  0.000000  0.621555  0.491349  0.237890
# 2  0.657604  0.722652  0.000000  0.974276
# 3  0.011049  0.584734  0.086839  0.993345
# 4  0.075121  0.664065  0.953025  0.446472
# 5  0.700973  0.819059  0.895355  0.000000
# 6  0.075758  0.935040  0.380271  0.000000
# 7  0.670879  0.699581  0.185698  0.000000
# 8  0.442609  0.636605  0.240343  0.000000
# 9  0.767131  0.269840  0.945019  0.000000

# %%
df.fillna(method='ffill')
# Out:
#           0         1         2         3
# 0  0.199320  0.632975  0.310385  0.937925
# 1  0.199320  0.621555  0.491349  0.237890
# 2  0.657604  0.722652  0.491349  0.974276
# 3  0.011049  0.584734  0.086839  0.993345
# 4  0.075121  0.664065  0.953025  0.446472
# 5  0.700973  0.819059  0.895355  0.446472
# 6  0.075758  0.935040  0.380271  0.446472
# 7  0.670879  0.699581  0.185698  0.446472
# 8  0.442609  0.636605  0.240343  0.446472
# 9  0.767131  0.269840  0.945019  0.446472

# %%
#　各カラムの平均値(確認用)
df.mean()
# Out:
# 0    0.400049
# 1    0.658611
# 2    0.498698
# 3    0.717982
# dtype: float64

# %%
# 平均値で埋める
df.fillna(df.mean())
# Out:
#           0         1         2         3
# 0  0.199320  0.632975  0.310385  0.937925
# 1  0.400049  0.621555  0.491349  0.237890
# 2  0.657604  0.722652  0.498698  0.974276
# 3  0.011049  0.584734  0.086839  0.993345
# 4  0.075121  0.664065  0.953025  0.446472
# 5  0.700973  0.819059  0.895355  0.717982
# 6  0.075758  0.935040  0.380271  0.717982
# 7  0.670879  0.699581  0.185698  0.717982
# 8  0.442609  0.636605  0.240343  0.717982
# 9  0.767131  0.269840  0.945019  0.717982

# %% [markdown]
# ________________________________________________________________________________________________________

# %%
import pandas_datareader.data as pdr
# Out:
# /Users/koretsunobuyasu/.pyenv/versions/3.7.5/lib/python3.7/site-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
start_date = '2001/1/2'
end_date   = '2016/12/30'

fx_jpusdata = pdr.DataReader('DEXJPUS', 'fred', start_date, end_date)

# %%
fx_jpusdata.head()
# Out:
#             DEXJPUS
# DATE
# 2001-01-02   114.73
# 2001-01-03   114.26
# 2001-01-04   115.47
# 2001-01-05   116.19
# 2001-01-08   115.97

# %%
fx_jpusdata['2016-04']
# Out:
#             DEXJPUS
# DATE
# 2016-04-01   112.06
# 2016-04-04   111.18
# 2016-04-05   110.26
# 2016-04-06   109.63
# 2016-04-07   107.98
# 2016-04-08   108.36
# 2016-04-11   107.96
# 2016-04-12   108.54
# 2016-04-13   109.21
# 2016-04-14   109.20
# 2016-04-15   108.76
# 2016-04-18   108.85
# 2016-04-19   109.16
# 2016-04-20   109.51
# 2016-04-21   109.41
# 2016-04-22   111.50
# 2016-04-25   111.08
# 2016-04-26   111.23
# 2016-04-27   111.26
# 2016-04-28   108.55
# 2016-04-29   106.90

# %%
fx_jpusdata.resample('M').last().head()
# Out:
#             DEXJPUS
# DATE
# 2001-01-31   116.39
# 2001-02-28   117.28
# 2001-03-31   125.54
# 2001-04-30   123.57
# 2001-05-31   118.88

# %%
fx_jpusdata.resample('D').last().head()
# Out:
#             DEXJPUS
# DATE
# 2001-01-02   114.73
# 2001-01-03   114.26
# 2001-01-04   115.47
# 2001-01-05   116.19
# 2001-01-06      NaN

# %%
fx_jpusdata.resample('D').ffill().head()
# Out:
#             DEXJPUS
# DATE
# 2001-01-02   114.73
# 2001-01-03   114.26
# 2001-01-04   115.47
# 2001-01-05   116.19
# 2001-01-06   116.19

# %%
fx_jpusdata.shift(1).head()
# Out:
#             DEXJPUS
# DATE
# 2001-01-02      NaN
# 2001-01-03   114.73
# 2001-01-04   114.26
# 2001-01-05   115.47
# 2001-01-08   116.19

# %%
fx_jpusdata_ratio = fx_jpusdata / fx_jpusdata.shift(1)
fx_jpusdata_ratio.head()
# Out:
#              DEXJPUS
# DATE
# 2001-01-02       NaN
# 2001-01-03  0.995903
# 2001-01-04  1.010590
# 2001-01-05  1.006235
# 2001-01-08  0.998107

# %%
fx_jpusdata.head()
# Out:
#             DEXJPUS
# DATE
# 2001-01-02   114.73
# 2001-01-03   114.26
# 2001-01-04   115.47
# 2001-01-05   116.19
# 2001-01-08   115.97

# %%
fx_jpusdata.rolling(3).mean().head()
# Out:
#                DEXJPUS
# DATE
# 2001-01-02         NaN
# 2001-01-03         NaN
# 2001-01-04  114.820000
# 2001-01-05  115.306667
# 2001-01-08  115.876667

# %%
fx_jpusdata.rolling(3).std().head()
# Out:
#              DEXJPUS
# DATE
# 2001-01-02       NaN
# 2001-01-03       NaN
# 2001-01-04  0.610000
# 2001-01-05  0.975312
# 2001-01-08  0.368963
